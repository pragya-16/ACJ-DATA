# %%
import pandas as pd

# %%
df = pd.read_csv('UDISE_2023-24_Table_2.1.csv')

# %%
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace("-", "_")
df.columns = df.columns.str.lower()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.head()
# Out:
#    sl._no.               india/state/ut  total_number_of___schools  \
# 0        1                        India                    1471891
# 1        2  Andaman and Nicobar Islands                        412
# 2        3               Andhra Pradesh                      61373
# 3        4            Arunachal Pradesh                       3490
# 4        5                        Assam                      56630
#
#    total_number_of___enrolments  total_number_of___teachers  \
# 0                     248045828                     9807600
# 1                         72119                        5750
# 2                       8741885                      338293
# 3                        323717                       24700
# 4                       6922533                      342199
#
#    percentage_share_of_schools_by_category___primary  \
# 0                                              50.00
# 1                                              50.70
# 2                                              61.50
# 3                                              48.60
# 4                                              66.20
#
#    percentage_share_of_schools_by_category___upper_primary  \
# 0                                              29.40
# 1                                              19.20
# 2                                              13.50
# 3                                              36.80
# 4                                              16.70
#
#    percentage_share_of_schools_by_category___secondary  \
# 0                                               9.80
# 1                                              13.10
# 2                                              18.90
# 3                                               9.50
# 4                                              12.50
#
#    percentage_share_of_schools_by_category___higher_secondary  \
# 0                                              10.80
# 1                                              17.00
# 2                                               6.10
# 3                                               5.20
# 4                                               4.70
#
#    percentage_share_of_enrolments_by_level____primary_  \
# 0                                              48.70
# 1                                              46.10
# 2                                              46.10
# 3                                              53.70
# 4                                              53.40
#
#    percentage_share_of_enrolments_by_level____upper_primary_  \
# 0                                              25.40
# 1                                              23.60
# 2                                              25.70
# 3                                              24.00
# 4                                              25.10
#
#    percentage_share_of_enrolments_by_level___secondary  \
# 0                                              14.90
# 1                                              15.90
# 2                                              16.50
# 3                                              13.40
# 4                                              14.30
#
#    percentage_share_of_enrolments_by_level___higher_secondary  \
# 0                                              10.90
# 1                                              14.40
# 2                                              11.60
# 3                                               8.90
# 4                                               7.20
#
#    percentage_share_of_teachers_by_school_category___primary  \
# 0                                              24.00
# 1                                              17.30
# 2                                              28.60
# 3                                              19.10
# 4                                              32.60
#
#    percentage_share_of_teachers_by_school_category___upper_primary  \
# 0                                              28.60
# 1                                              16.90
# 2                                              14.00
# 3                                              42.60
# 4                                              20.50
#
#    percentage_share_of_teachers_by_school_category___secondary  \
# 0                                              16.20
# 1                                              17.50
# 2                                              42.70
# 3                                              20.60
# 4                                              29.10
#
#    percentage_share_of_teachers_by_school_category___higher_secondary
# 0                                              31.10
# 1                                              48.30
# 2                                              14.70
# 3                                              17.60
# 4                                              17.80

# %%
df.tail(8)
# Out:
#     sl._no. india/state/ut  total_number_of___schools  \
# 29       30      Rajasthan                     107757
# 30       31         Sikkim                       1254
# 31       32     Tamil Nadu                      58722
# 32       33      Telangana                      42901
# 33       34        Tripura                       4923
# 34       35  Uttar Pradesh                     255087
# 35       36    Uttarakhand                      22551
# 36       37    West Bengal                      93945
#
#     total_number_of___enrolments  total_number_of___teachers  \
# 29                      16786065                      775745
# 30                        121395                       15489
# 31                      12993050                      550558
# 32                       7293644                      341460
# 33                        689408                       37661
# 34                      41662794                     1538479
# 35                       2372400                      130741
# 36                      18015525                      576557
#
#     percentage_share_of_schools_by_category___primary  \
# 29                                              35.00
# 30                                              53.30
# 31                                              57.90
# 32                                              47.90
# 33                                              50.20
# 34                                              52.30
# 35                                              57.30
# 36                                              79.30
#
#     percentage_share_of_schools_by_category___upper_primary  \
# 29                                              32.00
# 30                                              25.10
# 31                                              17.10
# 32                                              17.40
# 33                                              25.30
# 34                                              34.00
# 35                                              24.40
# 36                                               9.20
#
#     percentage_share_of_schools_by_category___secondary  \
# 29                                               6.80
# 30                                              11.50
# 31                                               9.70
# 32                                              27.00
# 33                                              13.60
# 34                                               4.70
# 35                                               6.20
# 36                                               3.50
#
#     percentage_share_of_schools_by_category___higher_secondary  \
# 29                                              26.10
# 30                                              10.10
# 31                                              15.30
# 32                                               7.70
# 33                                              10.80
# 34                                               9.00
# 35                                              12.00
# 36                                               8.10
#
#     percentage_share_of_enrolments_by_level____primary_  \
# 29                                              49.60
# 30                                              50.80
# 31                                              45.70
# 32                                              47.80
# 33                                              48.40
# 34                                              49.40
# 35                                              47.70
# 36                                              47.00
#
#     percentage_share_of_enrolments_by_level____upper_primary_  \
# 29                                              24.70
# 30                                              21.30
# 31                                              24.60
# 32                                              25.20
# 33                                              25.20
# 34                                              25.40
# 35                                              24.20
# 36                                              24.50
#
#     percentage_share_of_enrolments_by_level___secondary  \
# 29                                              14.50
# 30                                              14.90
# 31                                              15.90
# 32                                              15.30
# 33                                              14.60
# 34                                              13.70
# 35                                              15.00
# 36                                              17.00
#
#     percentage_share_of_enrolments_by_level___higher_secondary  \
# 29                                              11.20
# 30                                              13.00
# 31                                              13.80
# 32                                              11.80
# 33                                              11.80
# 34                                              11.50
# 35                                              13.10
# 36                                              11.50
#
#     percentage_share_of_teachers_by_school_category___primary  \
# 29                                              10.80
# 30                                              22.80
# 31                                              20.60
# 32                                              14.30
# 33                                              20.50
# 34                                              36.60
# 35                                              23.70
# 36                                              52.20
#
#     percentage_share_of_teachers_by_school_category___upper_primary  \
# 29                                              28.80
# 30                                              25.10
# 31                                              13.20
# 32                                              16.00
# 33                                              20.00
# 34                                              34.10
# 35                                              25.20
# 36                                               6.70
#
#     percentage_share_of_teachers_by_school_category___secondary  \
# 29                                               9.20
# 30                                              19.70
# 31                                              12.50
# 32                                              52.70
# 33                                              21.80
# 34                                               5.60
# 35                                               8.80
# 36                                               6.50
#
#     percentage_share_of_teachers_by_school_category___higher_secondary
# 29                                              51.20
# 30                                              32.40
# 31                                              53.80
# 32                                              16.90
# 33                                              37.60
# 34                                              23.70
# 35                                              42.30
# 36                                              34.60

# %%
df[df["total_number_of___schools"] > 100000][[
    "india/state/ut",
    "total_number_of___schools"
]]
# Out:
#     india/state/ut  total_number_of___schools
# 0            India                    1471891
# 20  Madhya Pradesh                     123412
# 21     Maharashtra                     108237
# 29       Rajasthan                     107757
# 34   Uttar Pradesh                     255087

# %%
df[[
    "india/state/ut",
    "percentage_share_of_schools_by_category___primary",
    "percentage_share_of_schools_by_category___upper_primary"
]].sort_values(
    "percentage_share_of_schools_by_category___primary",
    ascending=False
).head(10)
# Out:
#       india/state/ut  percentage_share_of_schools_by_category___primary  \
# 36       West Bengal                                              79.30
# 4              Assam                                              66.20
# 23         Meghalaya                                              62.70
# 2     Andhra Pradesh                                              61.50
# 13  Himachal Pradesh                                              60.80
# 10               Goa                                              58.00
# 31        Tamil Nadu                                              57.90
# 7       Chhattisgarh                                              57.30
# 35       Uttarakhand                                              57.30
# 30            Sikkim                                              53.30
#
#     percentage_share_of_schools_by_category___upper_primary
# 36                                               9.20
# 4                                               16.70
# 23                                              24.20
# 2                                               13.50
# 13                                              14.00
# 10                                               5.20
# 31                                              17.10
# 7                                               29.30
# 35                                              24.40
# 30                                              25.10

# %%
df["percentage_share_of_schools_by_category___secondary"].mean().round(2)
# Out:
# np.float64(12.77)

# %%
df["life_expectancy_years_total"].min()
